# %% [markdown]
# # Chapter5

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 33. Boolean統計量の計算

# %%
movie = pd.read_csv('Pandas-Cookbook-master/data/movie.csv', index_col='movie_title')
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
#
#                                                   gross  \
# movie_title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres  \
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
#                                             ... num_user_for_reviews  \
# movie_title                                 ...
# Avatar                                      ...               3054.0
# Pirates of the Caribbean: At World's End    ...               1238.0
# Spectre                                     ...                994.0
# The Dark Knight Rises                       ...               2701.0
# Star Wars: Episode VII - The Force Awakens  ...                  NaN
#
#                                             language  country content_rating  \
# movie_title
# Avatar                                       English      USA          PG-13
# Pirates of the Caribbean: At World's End     English      USA          PG-13
# Spectre                                      English       UK          PG-13
# The Dark Knight Rises                        English      USA          PG-13
# Star Wars: Episode VII - The Force Awakens       NaN      NaN            NaN
#
#                                                  budget title_year  \
# movie_title
# Avatar                                      237000000.0     2009.0
# Pirates of the Caribbean: At World's End    300000000.0     2007.0
# Spectre                                     245000000.0     2015.0
# The Dark Knight Rises                       250000000.0     2012.0
# Star Wars: Episode VII - The Force Awakens          NaN        NaN
#
#                                            actor_2_facebook_likes  imdb_score  \
# movie_title
# Avatar                                                      936.0         7.9
# Pirates of the Caribbean: At World's End                   5000.0         7.1
# Spectre                                                     393.0         6.8
# The Dark Knight Rises                                     23000.0         8.5
# Star Wars: Episode VII - The Force Awakens                   12.0         7.1
#
#                                            aspect_ratio movie_facebook_likes
# movie_title
# Avatar                                             1.78                33000
# Pirates of the Caribbean: At World's End           2.35                    0
# Spectre                                            2.35                85000
# The Dark Knight Rises                              2.35               164000
# Star Wars: Episode VII - The Force Awakens          NaN                    0
#
# [5 rows x 27 columns]

# %%
movie_2_hours = movie['duration'] > 120
movie_2_hours.head()
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# Name: duration, dtype: bool

# %%
movie_2_hours.sum()
# Out:
# 1039

# %%
movie_2_hours.mean()
# Out:
# 0.2113506916192026

# %%
movie['duration'].dropna().gt(120).mean()
# Out:
# 0.21199755152009794

# %%
movie_2_hours.describe()
# Out:
# count      4916
# unique        2
# top       False
# freq       3877
# Name: duration, dtype: object

# %%
movie_2_hours.value_counts(normalize=True)
# Out:
# False    0.788649
# True     0.211351
# Name: duration, dtype: float64

# %%
actors = movie[['actor_1_facebook_likes', 'actor_2_facebook_likes']].dropna()
(actors['actor_1_facebook_likes'] > actors['actor_2_facebook_likes']).mean()
# Out:
# 0.9777687130328371

# %% [markdown]
# # 34. 複数のBoolean条件の構築

# %% [markdown]
# - 一般的な論理演算子```and or not```は標準比較演算子（```< > == != <= >=```）よりも優先順位が高い
# - pandasの論理演算子（```& | ~```）は標準比較演算子（```< > == != <= >=```）よりも優先順位が上

# %%
movie = pd.read_csv('Pandas-Cookbook-master/data/movie.csv', index_col='movie_title')
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
#
#                                                   gross  \
# movie_title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres  \
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
#                                             ... num_user_for_reviews  \
# movie_title                                 ...
# Avatar                                      ...               3054.0
# Pirates of the Caribbean: At World's End    ...               1238.0
# Spectre                                     ...                994.0
# The Dark Knight Rises                       ...               2701.0
# Star Wars: Episode VII - The Force Awakens  ...                  NaN
#
#                                             language  country content_rating  \
# movie_title
# Avatar                                       English      USA          PG-13
# Pirates of the Caribbean: At World's End     English      USA          PG-13
# Spectre                                      English       UK          PG-13
# The Dark Knight Rises                        English      USA          PG-13
# Star Wars: Episode VII - The Force Awakens       NaN      NaN            NaN
#
#                                                  budget title_year  \
# movie_title
# Avatar                                      237000000.0     2009.0
# Pirates of the Caribbean: At World's End    300000000.0     2007.0
# Spectre                                     245000000.0     2015.0
# The Dark Knight Rises                       250000000.0     2012.0
# Star Wars: Episode VII - The Force Awakens          NaN        NaN
#
#                                            actor_2_facebook_likes  imdb_score  \
# movie_title
# Avatar                                                      936.0         7.9
# Pirates of the Caribbean: At World's End                   5000.0         7.1
# Spectre                                                     393.0         6.8
# The Dark Knight Rises                                     23000.0         8.5
# Star Wars: Episode VII - The Force Awakens                   12.0         7.1
#
#                                            aspect_ratio movie_facebook_likes
# movie_title
# Avatar                                             1.78                33000
# Pirates of the Caribbean: At World's End           2.35                    0
# Spectre                                            2.35                85000
# The Dark Knight Rises                              2.35               164000
# Star Wars: Episode VII - The Force Awakens          NaN                    0
#
# [5 rows x 27 columns]

# %%
criteria1 = movie.imdb_score > 8
criteria2 = movie.content_rating == 'PG-13'
criteria3 = ((movie.title_year < 2000) | (movie.title_year > 2009))
criteria2.head()
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# Name: content_rating, dtype: bool

# %%
criteria_final = criteria1 & criteria2 & criteria3
criteria_final.head()
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# dtype: bool

# %%
 5 > 10 and 3 > 4
# Out:
# False

# %%
True and 3 > 4
# Out:
# False

# %%
True and False
# Out:
# False

# %% [markdown]
# # 35. Booleanインデックス法によるフィルタリング

# %%
movie = pd.read_csv('Pandas-Cookbook-master/data/movie.csv', index_col='movie_title')

# %%
crit_a1 = movie.imdb_score > 8
crit_a2 = movie.content_rating == 'PG-13'
crit_a3 = (movie.title_year < 2000) | (movie.title_year > 2009)
final_crit_a = crit_a1 & crit_a2 & crit_a3

# %%
crit_b1 = movie.imdb_score < 5
crit_b2 = movie.content_rating == 'R'
crit_b3 = ((movie.title_year >= 2000) & (movie.title_year <= 2010))
final_crit_b = crit_b1 & crit_b2 & crit_b3

# %%
final_crit_all = final_crit_a | final_crit_b
final_crit_all.head()
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# dtype: bool

# %%
movie[final_crit_all].head()
# Out:
#                             color      director_name  num_critic_for_reviews  \
# movie_title
# The Dark Knight Rises       Color  Christopher Nolan                   813.0
# The Avengers                Color        Joss Whedon                   703.0
# Captain America: Civil War  Color      Anthony Russo                   516.0
# Guardians of the Galaxy     Color         James Gunn                   653.0
# Interstellar                Color  Christopher Nolan                   712.0
#
#                             duration  director_facebook_likes  \
# movie_title
# The Dark Knight Rises          164.0                  22000.0
# The Avengers                   173.0                      0.0
# Captain America: Civil War     147.0                     94.0
# Guardians of the Galaxy        121.0                    571.0
# Interstellar                   169.0                  22000.0
#
#                             actor_3_facebook_likes        actor_2_name  \
# movie_title
# The Dark Knight Rises                      23000.0      Christian Bale
# The Avengers                               19000.0   Robert Downey Jr.
# Captain America: Civil War                 11000.0  Scarlett Johansson
# Guardians of the Galaxy                     3000.0          Vin Diesel
# Interstellar                                6000.0       Anne Hathaway
#
#                             actor_1_facebook_likes        gross  \
# movie_title
# The Dark Knight Rises                      27000.0  448130642.0
# The Avengers                               26000.0  623279547.0
# Captain America: Civil War                 21000.0  407197282.0
# Guardians of the Galaxy                    14000.0  333130696.0
# Interstellar                               11000.0  187991439.0
#
#                                              genres  ... num_user_for_reviews  \
# movie_title                                          ...
# The Dark Knight Rises               Action|Thriller  ...               2701.0
# The Avengers                Action|Adventure|Sci-Fi  ...               1722.0
# Captain America: Civil War  Action|Adventure|Sci-Fi  ...               1022.0
# Guardians of the Galaxy     Action|Adventure|Sci-Fi  ...               1097.0
# Interstellar                 Adventure|Drama|Sci-Fi  ...               2725.0
#
#                             language  country content_rating       budget  \
# movie_title
# The Dark Knight Rises        English      USA          PG-13  250000000.0
# The Avengers                 English      USA          PG-13  220000000.0
# Captain America: Civil War   English      USA          PG-13  250000000.0
# Guardians of the Galaxy      English      USA          PG-13  170000000.0
# Interstellar                 English      USA          PG-13  165000000.0
#
#                            title_year actor_2_facebook_likes  imdb_score  \
# movie_title
# The Dark Knight Rises          2012.0                23000.0         8.5
# The Avengers                   2012.0                21000.0         8.1
# Captain America: Civil War     2016.0                19000.0         8.2
# Guardians of the Galaxy        2014.0                14000.0         8.1
# Interstellar                   2014.0                11000.0         8.6
#
#                            aspect_ratio movie_facebook_likes
# movie_title
# The Dark Knight Rises              2.35               164000
# The Avengers                       1.85               123000
# Captain America: Civil War         2.35                72000
# Guardians of the Galaxy            2.35                96000
# Interstellar                       2.35               349000
#
# [5 rows x 27 columns]

# %%
cols = ['imdb_score', 'content_rating', 'title_year']
movie_filtered = movie.loc[final_crit_all, cols]
movie_filtered.head()
# Out:
#                             imdb_score content_rating  title_year
# movie_title
# The Dark Knight Rises              8.5          PG-13      2012.0
# The Avengers                       8.1          PG-13      2012.0
# Captain America: Civil War         8.2          PG-13      2016.0
# Guardians of the Galaxy            8.1          PG-13      2014.0
# Interstellar                       8.6          PG-13      2014.0

# %%
final_crit_a2 = (movie.imdb_score > 8) & \
                (movie.content_rating == 'PG-13') & \
                ((movie.title_year < 2000) | (movie.title_year > 2009))
final_crit_a2.equals(final_crit_a)
# Out:
# True

# %% [markdown]
# # 36. インデックス選択によるBooleanインデックス法の代用

# %%
college = pd.read_csv('Pandas-Cookbook-master/data/college.csv')

# %%
college[college['STABBR'] == 'TX'].head()
# Out:
#                             INSTNM        CITY STABBR  HBCU  MENONLY  \
# 3610  Abilene Christian University     Abilene     TX   0.0      0.0
# 3611       Alvin Community College       Alvin     TX   0.0      0.0
# 3612              Amarillo College    Amarillo     TX   0.0      0.0
# 3613              Angelina College      Lufkin     TX   0.0      0.0
# 3614       Angelo State University  San Angelo     TX   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 3610        0.0         1     530.0     545.0           0.0  ...     0.0454
# 3611        0.0         0       NaN       NaN           0.0  ...     0.0002
# 3612        0.0         0       NaN       NaN           0.0  ...     0.0000
# 3613        0.0         0       NaN       NaN           0.0  ...     0.0264
# 3614        0.0         0     475.0     490.0           0.0  ...     0.0285
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 3610    0.0423     0.0045    0.0468         1   0.2595    0.5527   0.0381
# 3611    0.0000     0.0143    0.7123         1   0.1549    0.0625   0.2841
# 3612    0.0001     0.0085    0.6922         1   0.3786    0.1573   0.3431
# 3613    0.0005     0.0000    0.5600         1   0.5308    0.0000   0.2603
# 3614    0.0331     0.0011    0.1289         1   0.4068    0.5279   0.1407
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3610            40200               25985
# 3611            34500                6750
# 3612            31700               10950
# 3613            26900   PrivacySuppressed
# 3614            37700             21319.5
#
# [5 rows x 27 columns]

# %%
college2 = college.set_index('STABBR')
college2.loc['TX'].head()
# Out:
#                               INSTNM        CITY  HBCU  MENONLY  WOMENONLY  \
# STABBR
# TX      Abilene Christian University     Abilene   0.0      0.0        0.0
# TX           Alvin Community College       Alvin   0.0      0.0        0.0
# TX                  Amarillo College    Amarillo   0.0      0.0        0.0
# TX                  Angelina College      Lufkin   0.0      0.0        0.0
# TX           Angelo State University  San Angelo   0.0      0.0        0.0
#
#         RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY    UGDS  ...  UGDS_2MOR  \
# STABBR                                                      ...
# TX             1     530.0     545.0           0.0  3572.0  ...     0.0454
# TX             0       NaN       NaN           0.0  4682.0  ...     0.0002
# TX             0       NaN       NaN           0.0  9346.0  ...     0.0000
# TX             0       NaN       NaN           0.0  3825.0  ...     0.0264
# TX             0     475.0     490.0           0.0  5290.0  ...     0.0285
#
#         UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# STABBR
# TX        0.0423     0.0045    0.0468         1   0.2595    0.5527   0.0381
# TX        0.0000     0.0143    0.7123         1   0.1549    0.0625   0.2841
# TX        0.0001     0.0085    0.6922         1   0.3786    0.1573   0.3431
# TX        0.0005     0.0000    0.5600         1   0.5308    0.0000   0.2603
# TX        0.0331     0.0011    0.1289         1   0.4068    0.5279   0.1407
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# STABBR
# TX                40200               25985
# TX                34500                6750
# TX                31700               10950
# TX                26900   PrivacySuppressed
# TX                37700             21319.5
#
# [5 rows x 26 columns]

# %%
# Booleanインデックス法の速度
# %timeit college[college['STABBR']=='TX']
# Out:
# 718 µs ± 15.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# インデックス選択法
# %timeit college2.loc['TX']
# Out:
# 357 µs ± 2.28 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit college2 = college.set_index('STABBR')
# Out:
# 836 µs ± 4.43 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# 複数のカラムの選択
states = ['TX', 'CA', 'NY']
college[college['STABBR'].isin(states)].filter(like='STABBR').head()
# Out:
#     STABBR
# 192     CA
# 193     CA
# 194     CA
# 195     CA
# 196     CA

# %% [markdown]
# # 37. 重複のないインデックスとソートしたインデックスによる選択

# %%
college = pd.read_csv('Pandas-Cookbook-master/data/college.csv')

# %%
college2 = college.set_index('STABBR')
college2.index.is_monotonic
# Out:
# False

# %%
college3 = college2.sort_index()
college3.index.is_monotonic
# Out:
# True

# %%
# %timeit college[college['STABBR'] == 'TX']
# Out:
# 702 µs ± 19.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit college2.loc['TX']
# Out:
# 357 µs ± 3.93 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# ソートしたインデックスが一番検索が早い
# %timeit college3.loc['TX']
# Out:
# 52.9 µs ± 270 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# 校名をインデックスにし、重複がないか確認
college_unique = college.set_index('INSTNM')
college_unique.index.is_unique
# Out:
# True

# %%
college[college['INSTNM'] == 'Stanford University']
# Out:
#                    INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 4217  Stanford University  Stanford     CA   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 4217         0     730.0     745.0           0.0  ...     0.1067    0.0819
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 4217     0.0031       0.0         1   0.1556    0.1256   0.0401
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4217            86000               12782
#
# [1 rows x 27 columns]

# %%
college_unique.loc['Stanford University']
# Out:
# CITY                  Stanford
# STABBR                      CA
# HBCU                         0
# MENONLY                      0
# WOMENONLY                    0
# RELAFFIL                     0
# SATVRMID                   730
# SATMTMID                   745
# DISTANCEONLY                 0
# UGDS                      7018
# UGDS_WHITE              0.3752
# UGDS_BLACK              0.0591
# UGDS_HISP               0.1607
# UGDS_ASIAN              0.1979
# UGDS_AIAN               0.0114
# UGDS_NHPI               0.0038
# UGDS_2MOR               0.1067
# UGDS_NRA                0.0819
# UGDS_UNKN               0.0031
# PPTUG_EF                     0
# CURROPER                     1
# PCTPELL                 0.1556
# PCTFLOAN                0.1256
# UG25ABV                 0.0401
# MD_EARN_WNE_P10          86000
# GRAD_DEBT_MDN_SUPP       12782
# Name: Stanford University, dtype: object

# %%
# %timeit college[college['INSTNM'] == 'Stanford University']
# Out:
# 622 µs ± 8.03 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit college_unique.loc['Stanford University']
# Out:
# 109 µs ± 1.18 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# インデックスを複数列（都市と州）の組み合わせにする
college.index = college['CITY'] + ', '  + college['STABBR']
college = college.sort_index()
college.head()
# Out:
#                                  INSTNM      CITY STABBR  HBCU  MENONLY  \
# ARTESIA, CA           Angeles Institute   ARTESIA     CA   0.0      0.0
# Aberdeen, SD       Presentation College  Aberdeen     SD   0.0      0.0
# Aberdeen, SD  Northern State University  Aberdeen     SD   0.0      0.0
# Aberdeen, WA       Grays Harbor College  Aberdeen     WA   0.0      0.0
# Abilene, TX   Hardin-Simmons University   Abilene     TX   0.0      0.0
#
#               WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# ARTESIA, CA         0.0         0       NaN       NaN           0.0  ...
# Aberdeen, SD        0.0         1     440.0     480.0           0.0  ...
# Aberdeen, SD        0.0         0     480.0     475.0           0.0  ...
# Aberdeen, WA        0.0         0       NaN       NaN           0.0  ...
# Abilene, TX         0.0         1     508.0     515.0           0.0  ...
#
#               UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# ARTESIA, CA      0.0175    0.0088     0.0088    0.0000         1   0.6275
# Aberdeen, SD     0.0284    0.0142     0.0823    0.2865         1   0.4829
# Aberdeen, SD     0.0219    0.0425     0.0024    0.1872         1   0.2272
# Aberdeen, WA     0.0937    0.0009     0.0250    0.1820         1   0.4530
# Abilene, TX      0.0298    0.0159     0.0102    0.0685         1   0.3256
#
#               PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# ARTESIA, CA     0.8138   0.5429              NaN               16850
# Aberdeen, SD    0.7560   0.3097            35900               25000
# Aberdeen, SD    0.4303   0.1766            33600               24847
# Aberdeen, WA    0.1502   0.5087            27000               11490
# Abilene, TX     0.5547   0.0982            38700               25864
#
# [5 rows x 27 columns]

# %%
college.loc['Miami, FL'].head()
# Out:
#                                               INSTNM   CITY STABBR  HBCU  \
# Miami, FL        New Professions Technical Institute  Miami     FL   0.0
# Miami, FL               Management Resources College  Miami     FL   0.0
# Miami, FL                   Strayer University-Doral  Miami     FL   NaN
# Miami, FL                   Keiser University- Miami  Miami     FL   NaN
# Miami, FL  George T Baker Aviation Technical College  Miami     FL   0.0
#
#            MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# Miami, FL      0.0        0.0         0       NaN       NaN           0.0
# Miami, FL      0.0        0.0         0       NaN       NaN           0.0
# Miami, FL      NaN        NaN         1       NaN       NaN           NaN
# Miami, FL      NaN        NaN         1       NaN       NaN           NaN
# Miami, FL      0.0        0.0         0       NaN       NaN           0.0
#
#            ...  UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# Miami, FL  ...     0.0000       0.0        0.0    0.4464         1   0.8701
# Miami, FL  ...     0.0000       0.0        0.0    0.0000         1   0.4239
# Miami, FL  ...        NaN       NaN        NaN       NaN         1      NaN
# Miami, FL  ...        NaN       NaN        NaN       NaN         1      NaN
# Miami, FL  ...     0.0046       0.0        0.0    0.5686         1   0.2567
#
#            PCTFLOAN  UG25ABV    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# Miami, FL    0.6780   0.8358              18700                8682
# Miami, FL    0.5458   0.8698  PrivacySuppressed               12182
# Miami, FL       NaN      NaN              49200             36173.5
# Miami, FL       NaN      NaN              29700               26063
# Miami, FL    0.0000   0.4366              38600   PrivacySuppressed
#
# [5 rows x 27 columns]

# %%
# %%timeit
crit1 = college['CITY'] == 'Miami'
crit2 = college['STABBR'] == 'FL'
college[crit1 & crit2]
# Out:
# 1.17 ms ± 31.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit college.loc['Miami, FL']
# Out:
# 53 µs ± 495 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# # 38. 株価見直しの計算

# %%
slb = pd.read_csv('Pandas-Cookbook-master/data/slb_stock.csv', index_col='Date', parse_dates=['Date'])
slb.head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2010-01-04  66.39  67.20  66.12  67.11   5771234
# 2010-01-05  66.99  67.62  66.73  67.30   7366270
# 2010-01-06  67.17  68.94  67.03  68.80   9949946
# 2010-01-07  68.49  69.81  68.21  69.51   7700297
# 2010-01-08  69.19  72.00  69.09  70.65  13487621

# %%
# 終値の要約統計量
slb_close = slb['Close']
slb_summary = slb_close.describe(percentiles=[.1, .9])
slb_summary
# Out:
# count    1895.000000
# mean       79.121905
# std        11.767802
# min        51.750000
# 10%        64.892000
# 50%        78.000000
# 90%        93.248000
# max       117.950000
# Name: Close, dtype: float64

# %%
# 最高、最低の10パーセントタイル内の終値を選ぶ
upper_10 = slb_summary.loc['90%']
lower_10 = slb_summary.loc['10%']
criteria = (slb_close < lower_10) | (slb_close > upper_10)
slb_top_bottom_10 = slb_close[criteria]

# %%
slb_close.plot(color='black', figsize=(12, 6))
slb_top_bottom_10.plot(marker='o', style=' ', ms=4, color='lightgray')
xmin = criteria.index[0]
xmax = criteria.index[-1]
plt.hlines(y=[lower_10, upper_10], xmin=xmin, xmax=xmax, color='black')

# %%
slb_close.plot(color='black', figsize=(12, 4))
plt.hlines(y=[lower_10, upper_10], xmin=xmin, xmax=xmax, color='lightgray')
plt.fill_between(x=criteria.index, y1=lower_10, y2=slb_close.values, color='black')
plt.fill_between(x=criteria.index, y1=lower_10, y2=slb_close.values, where=slb_close < lower_10, color='lightgray')
plt.fill_between(x=criteria.index, y1=upper_10, y2=slb_close.values, where=slb_close > upper_10, color='lightgray')

# %%
# レシピ39 SQLのWHERE節の翻訳

# %%
employee = pd.read_csv('Pandas-Cookbook-master/data/employee.csv')
employee.head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18
# 2  2015-02-03  2015-02-03
# 3  1982-02-08  1991-05-25
# 4  1989-06-19  1994-10-22

# %%
employee.columns
# Out:
# Index(['UNIQUE_ID', 'POSITION_TITLE', 'DEPARTMENT', 'BASE_SALARY', 'RACE',
#        'EMPLOYMENT_TYPE', 'GENDER', 'EMPLOYMENT_STATUS', 'HIRE_DATE',
#        'JOB_DATE'],
#       dtype='object')

# %%
employee.DEPARTMENT.value_counts().head()
# Out:
# Houston Police Department-HPD     638
# Houston Fire Department (HFD)     384
# Public Works & Engineering-PWE    343
# Health & Human Services           110
# Houston Airport System (HAS)      106
# Name: DEPARTMENT, dtype: int64

# %%
# フィルタリング基準ごとに1つの文を書く
depts = ['Houston Police Department-HPD', 
             'Houston Fire Department (HFD)']
criteria_dept = employee.DEPARTMENT.isin(depts)
criteria_gender = employee.GENDER == 'Female'
criteria_sal = (employee.BASE_SALARY >= 80000) & \
               (employee.BASE_SALARY <= 120000)

# %%
# すべてのBoolean indexを組み合わせる
criteria_final = criteria_dept & criteria_gender & criteria_sal

# %%
# 作成したBoolean値でフィルタリング
select_columns = ['UNIQUE_ID', 'DEPARTMENT', 'GENDER', 'BASE_SALARY']
employee.loc[criteria_final, select_columns].head()
# Out:
#      UNIQUE_ID                     DEPARTMENT  GENDER  BASE_SALARY
# 61          61  Houston Fire Department (HFD)  Female      96668.0
# 136        136  Houston Police Department-HPD  Female      81239.0
# 367        367  Houston Police Department-HPD  Female      86534.0
# 474        474  Houston Police Department-HPD  Female      91181.0
# 513        513  Houston Police Department-HPD  Female      81239.0

# %%
# 給与基準
criteria_sal = employee.BASE_SALARY.between(8000, 12000)

# %%
# 人数の多い上位5部門を除く
top_5_depts = employee.DEPARTMENT.value_counts()
criteria = ~employee.DEPARTMENT.isin(top_5_depts)
employee[criteria].head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18
# 2  2015-02-03  2015-02-03
# 3  1982-02-08  1991-05-25
# 4  1989-06-19  1994-10-22

# %% [markdown]
# # 40. 株式収益率の正規度判定

# %%
# 正規分布に従わないデータを扱ってみる
# amazonの株価
amzn = pd.read_csv('Pandas-Cookbook-master/data/amzn_stock.csv', index_col='Date', parse_dates=['Date'])
amzn.head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2010-01-04  136.25  136.61  133.14  133.90   7600543
# 2010-01-05  133.43  135.48  131.81  134.69   8856456
# 2010-01-06  134.60  134.73  131.65  132.25   7180977
# 2010-01-07  132.01  132.32  128.80  130.00  11030124
# 2010-01-08  130.56  133.68  129.03  133.52   9833829

# %%
# 前日との終値の差（%）
amzn_daily_return = amzn.Close.pct_change()
# 欠損値削除
amzn_daily_return = amzn_daily_return.dropna()
amzn_daily_return.head()
# Out:
# Date
# 2010-01-05    0.005900
# 2010-01-06   -0.018116
# 2010-01-07   -0.017013
# 2010-01-08    0.027077
# 2010-01-11   -0.024041
# Name: Close, dtype: float64

# %%
amzn_daily_return.hist()
# Out:
# <AxesSubplot:>

# %%
# 平均と標準偏差を算出
mean = amzn_daily_return.mean()
std = amzn_daily_return.std()
mean, std
# Out:
# (0.0012631309530525448, 0.019861559267099153)

# %%
# z-score （日時収益率-平均）の絶対値を標準偏差で割る
abs_z_score = amzn_daily_return.sub(mean).abs().div(std)
abs_z_score
# Out:
# Date
# 2010-01-05    0.233456
# 2010-01-06    0.975694
# 2010-01-07    0.920188
# 2010-01-08    1.299686
# 2010-01-11    1.274043
#                 ...
# 2017-07-11    0.181830
# 2017-07-12    0.563398
# 2017-07-13    0.357731
# 2017-07-14    0.004223
# 2017-07-17    0.350023
# Name: Close, Length: 1895, dtype: float64

# %%
# 日時収益率が平均から1,2,3標準偏差に収まるパーセントを計算する
pcts = [abs_z_score.lt(i).mean() for i in range(1,4)]
pcts
# Out:
# [0.7873350923482849, 0.9562005277044855, 0.9846965699208443]

# %%
# 68-95-99.7規則に従うかを確認
print('{:.3f} fall within 1 standard deviation. '
      '{:3f} within 2 and {:.3f} within 2'.format(*pcts))
# Out:
# 0.787 fall within 1 standard deviation. 0.956201 within 2 and 0.985 within 2

# %%
# 関数として処理をまとめる
def test_return_normality(stock_data):
    close = stock_data['Close']
    daily_return = close.pct_change().dropna()
    daily_return.hist(bins=20)
    mean = daily_return.mean()
    std = daily_return.std()
    abs_z_score = abs(daily_return - mean)/std
    pcts = [abs_z_score.lt(i).mean() for i in range(1, 4)]
    
    print('{:.3f} fall within 1 standard deviation. '
      '{:3f} within 2 and {:.3f} within 2'.format(*pcts))

# %%
slb = pd.read_csv('Pandas-Cookbook-master/data/slb_stock.csv', index_col='Date', parse_dates=['Date'])
slb.head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2010-01-04  66.39  67.20  66.12  67.11   5771234
# 2010-01-05  66.99  67.62  66.73  67.30   7366270
# 2010-01-06  67.17  68.94  67.03  68.80   9949946
# 2010-01-07  68.49  69.81  68.21  69.51   7700297
# 2010-01-08  69.19  72.00  69.09  70.65  13487621

# %%
slb.Close.hist()
# Out:
# <AxesSubplot:>

# %%
test_return_normality(slb)
# Out:
# 0.742 fall within 1 standard deviation. 0.945618 within 2 and 0.986 within 2

# %% [markdown]
# # 41. queryメソッドによるBooleanインデックス法の読みやすさ改善

# %%
employee = pd.read_csv('Pandas-Cookbook-master/data/employee.csv')
employee.head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18
# 2  2015-02-03  2015-02-03
# 3  1982-02-08  1991-05-25
# 4  1989-06-19  1994-10-22

# %%
# 部門を指定する
depts = ['Houston Police Department-HPD', 'Houston Fire Department (HFD)']
# カラムを指定する
select_columns = ['UNIQUE_ID', 'DEPARTMENT', 'GENDER', 'BASE_SALARY']

# %%
# クエリ文字列（抽出条件）を作成する
# 二重不等式を1つの式で表わせ、Booleanインデックス法のように記号（&,|,~）を使わない
# @変数でPython変数を参照する
qs = "DEPARTMENT in @depts" \
     " and GENDER == 'Female'" \
     " and 80000 <= BASE_SALARY <= 120000"
qs
# Out:
# "DEPARTMENT in @depts and GENDER == 'Female' and 80000 <= BASE_SALARY <= 120000"

# %%
# クエリを実行し行を絞る→列を絞る
emp_filtered = employee.query(qs)
emp_filtered[select_columns].head()
# Out:
#      UNIQUE_ID                     DEPARTMENT  GENDER  BASE_SALARY
# 61          61  Houston Fire Department (HFD)  Female      96668.0
# 136        136  Houston Police Department-HPD  Female      81239.0
# 367        367  Houston Police Department-HPD  Female      86534.0
# 474        474  Houston Police Department-HPD  Female      91181.0
# 513        513  Houston Police Department-HPD  Female      81239.0

# %%
# 人数が多い上位10部門以外の女性従業員を求める
top10_depts = employee.DEPARTMENT.value_counts().index[:10].tolist()
qs = "DEPARTMENT not in @top10_depts and GENDER == 'Female'"
employee_filtered2 = employee.query(qs)
employee_filtered2.head()
# Out:
#      UNIQUE_ID                    POSITION_TITLE  \
# 0            0       ASSISTANT DIRECTOR (EX LVL)
# 73          73         ADMINISTRATIVE SPECIALIST
# 96          96     ASSISTANT CITY CONTROLLER III
# 117        117  SENIOR ASSISTANT CITY ATTORNEY I
# 146        146              SENIOR STAFF ANALYST
#
#                         DEPARTMENT  BASE_SALARY                       RACE  \
# 0      Municipal Courts Department     121862.0            Hispanic/Latino
# 73           Human Resources Dept.      55939.0  Black or African American
# 96        City Controller's Office      59077.0     Asian/Pacific Islander
# 117               Legal Department      90957.0  Black or African American
# 146  Houston Information Tech Svcs      74951.0                      White
#
#     EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE
# 0         Full Time  Female            Active  2006-06-12  2012-10-13
# 73        Full Time  Female            Active  2011-12-19  2013-11-23
# 96        Full Time  Female            Active  2013-06-10  2013-06-10
# 117       Full Time  Female            Active  1998-03-20  2012-07-21
# 146       Full Time  Female            Active  2014-03-17  2014-03-17

# %% [markdown]
# # 42. whereメソッドによるSeriesの保持

# %%
movie = pd.read_csv('Pandas-Cookbook-master/data/movie.csv', index_col='movie_title')
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
#
#                                                   gross  \
# movie_title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres  \
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
#                                             ... num_user_for_reviews  \
# movie_title                                 ...
# Avatar                                      ...               3054.0
# Pirates of the Caribbean: At World's End    ...               1238.0
# Spectre                                     ...                994.0
# The Dark Knight Rises                       ...               2701.0
# Star Wars: Episode VII - The Force Awakens  ...                  NaN
#
#                                             language  country content_rating  \
# movie_title
# Avatar                                       English      USA          PG-13
# Pirates of the Caribbean: At World's End     English      USA          PG-13
# Spectre                                      English       UK          PG-13
# The Dark Knight Rises                        English      USA          PG-13
# Star Wars: Episode VII - The Force Awakens       NaN      NaN            NaN
#
#                                                  budget title_year  \
# movie_title
# Avatar                                      237000000.0     2009.0
# Pirates of the Caribbean: At World's End    300000000.0     2007.0
# Spectre                                     245000000.0     2015.0
# The Dark Knight Rises                       250000000.0     2012.0
# Star Wars: Episode VII - The Force Awakens          NaN        NaN
#
#                                            actor_2_facebook_likes  imdb_score  \
# movie_title
# Avatar                                                      936.0         7.9
# Pirates of the Caribbean: At World's End                   5000.0         7.1
# Spectre                                                     393.0         6.8
# The Dark Knight Rises                                     23000.0         8.5
# Star Wars: Episode VII - The Force Awakens                   12.0         7.1
#
#                                            aspect_ratio movie_facebook_likes
# movie_title
# Avatar                                             1.78                33000
# Pirates of the Caribbean: At World's End           2.35                    0
# Spectre                                            2.35                85000
# The Dark Knight Rises                              2.35               164000
# Star Wars: Episode VII - The Force Awakens          NaN                    0
#
# [5 rows x 27 columns]

# %%
movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movie.isnull().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
fb_likes = movie['actor_1_facebook_likes'].dropna()
fb_likes.head()
# Out:
# movie_title
# Avatar                                         1000.0
# Pirates of the Caribbean: At World's End      40000.0
# Spectre                                       11000.0
# The Dark Knight Rises                         27000.0
# Star Wars: Episode VII - The Force Awakens      131.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
# 要約統計量
# 平均値が中央値に比べてかなり大きい　→　右に裾が長い
fb_likes.describe()
# Out:
# count      4909.000000
# mean       6494.488491
# std       15106.986884
# min           0.000000
# 25%         607.000000
# 50%         982.000000
# 75%       11000.000000
# max      640000.000000
# Name: actor_1_facebook_likes, dtype: float64

# %%
fb_likes.hist()
# Out:
# <AxesSubplot:>

# %%
criteria_high = fb_likes < 20000
criteria_high.mean().round(2)
# Out:
# 0.91

# %%
# Boolean条件を渡せるwhereメソッド
# Trueの場合は元々の値、Falseの値はNaNになる
fb_likes.where(criteria_high).head()
# Out:
# movie_title
# Avatar                                         1000.0
# Pirates of the Caribbean: At World's End          NaN
# Spectre                                       11000.0
# The Dark Knight Rises                             NaN
# Star Wars: Episode VII - The Force Awakens      131.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
# whereメソッドの第２パラメーターotherで置換する値を制御
# 欠損値(=20,000以上)をすべて20,000に変更
fb_likes.where(criteria_high, other=20000).head()
# Out:
# movie_title
# Avatar                                         1000.0
# Pirates of the Caribbean: At World's End      20000.0
# Spectre                                       11000.0
# The Dark Knight Rises                         20000.0
# Star Wars: Episode VII - The Force Awakens      131.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
# 300以下は300に、20,000以上は20,000にする
criteria_low = fb_likes > 300
fb_likes_cap =fb_likes.where(criteria_high, other=20000).where(criteria_low, other=300)
fb_likes_cap.head()
# Out:
# movie_title
# Avatar                                         1000.0
# Pirates of the Caribbean: At World's End      20000.0
# Spectre                                       11000.0
# The Dark Knight Rises                         20000.0
# Star Wars: Episode VII - The Force Awakens      300.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
len(fb_likes), len(fb_likes_cap)
# Out:
# (4909, 4909)

# %%
# 修正後ヒストグラム
fb_likes_cap.hist()
# Out:
# <AxesSubplot:>

# %%
# clipで切り上げ切り下げ処理を行う
fb_likes_cap2 = fb_likes.clip(lower=300, upper=20000)
fb_likes_cap2.equals(fb_likes_cap)
# Out:
# True

# %% [markdown]
# # 43. DataaFrameの行のマスキング

# %%
movie = pd.read_csv('Pandas-Cookbook-master/data/movie.csv', index_col='movie_title')
movie.title_year.head()
# Out:
# movie_title
# Avatar                                        2009.0
# Pirates of the Caribbean: At World's End      2007.0
# Spectre                                       2015.0
# The Dark Knight Rises                         2012.0
# Star Wars: Episode VII - The Force Awakens       NaN
# Name: title_year, dtype: float64

# %%
c1 = movie['title_year'] >= 2010
c2 = movie['title_year'].isnull()
criteria = c1 | c2
criteria.head()
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens     True
# Name: title_year, dtype: bool

# %%
# maskはwhereと反対の動き
# maskは引数がTrue(>=2010)の行を欠損値に、False（<2010）のときにを値をそのまま残す
movie.mask(criteria).head()
# Out:
#                                             color   director_name  \
# movie_title
# Avatar                                      Color   James Cameron
# Pirates of the Caribbean: At World's End    Color  Gore Verbinski
# Spectre                                       NaN             NaN
# The Dark Knight Rises                         NaN             NaN
# Star Wars: Episode VII - The Force Awakens    NaN             NaN
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                        NaN       NaN
# The Dark Knight Rises                                          NaN       NaN
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         NaN
# The Dark Knight Rises                                           NaN
# Star Wars: Episode VII - The Force Awakens                      NaN
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                        NaN
# The Dark Knight Rises                                          NaN
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                                  NaN
# The Dark Knight Rises                                    NaN
# Star Wars: Episode VII - The Force Awakens               NaN
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                        NaN
# The Dark Knight Rises                                          NaN
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                   gross  \
# movie_title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                             NaN
# The Dark Knight Rises                               NaN
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres  \
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                                                 NaN
# The Dark Knight Rises                                                   NaN
# Star Wars: Episode VII - The Force Awakens                              NaN
#
#                                             ... num_user_for_reviews  \
# movie_title                                 ...
# Avatar                                      ...               3054.0
# Pirates of the Caribbean: At World's End    ...               1238.0
# Spectre                                     ...                  NaN
# The Dark Knight Rises                       ...                  NaN
# Star Wars: Episode VII - The Force Awakens  ...                  NaN
#
#                                             language  country content_rating  \
# movie_title
# Avatar                                       English      USA          PG-13
# Pirates of the Caribbean: At World's End     English      USA          PG-13
# Spectre                                          NaN      NaN            NaN
# The Dark Knight Rises                            NaN      NaN            NaN
# Star Wars: Episode VII - The Force Awakens       NaN      NaN            NaN
#
#                                                  budget title_year  \
# movie_title
# Avatar                                      237000000.0     2009.0
# Pirates of the Caribbean: At World's End    300000000.0     2007.0
# Spectre                                             NaN        NaN
# The Dark Knight Rises                               NaN        NaN
# Star Wars: Episode VII - The Force Awakens          NaN        NaN
#
#                                            actor_2_facebook_likes  imdb_score  \
# movie_title
# Avatar                                                      936.0         7.9
# Pirates of the Caribbean: At World's End                   5000.0         7.1
# Spectre                                                       NaN         NaN
# The Dark Knight Rises                                         NaN         NaN
# Star Wars: Episode VII - The Force Awakens                    NaN         NaN
#
#                                            aspect_ratio movie_facebook_likes
# movie_title
# Avatar                                             1.78              33000.0
# Pirates of the Caribbean: At World's End           2.35                  0.0
# Spectre                                             NaN                  NaN
# The Dark Knight Rises                               NaN                  NaN
# Star Wars: Episode VII - The Force Awakens          NaN                  NaN
#
# [5 rows x 27 columns]

# %%
# 全部が欠損値の行を取り除く
movie_mask = movie.mask(criteria).dropna(how='all')
movie_mask.head()
# Out:
#                                           color   director_name  \
# movie_title
# Avatar                                    Color   James Cameron
# Pirates of the Caribbean: At World's End  Color  Gore Verbinski
# Spider-Man 3                              Color       Sam Raimi
# Harry Potter and the Half-Blood Prince    Color     David Yates
# Superman Returns                          Color    Bryan Singer
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                     723.0     178.0
# Pirates of the Caribbean: At World's End                   302.0     169.0
# Spider-Man 3                                               392.0     156.0
# Harry Potter and the Half-Blood Prince                     375.0     153.0
# Superman Returns                                           434.0     169.0
#
#                                           director_facebook_likes  \
# movie_title
# Avatar                                                        0.0
# Pirates of the Caribbean: At World's End                    563.0
# Spider-Man 3                                                  0.0
# Harry Potter and the Half-Blood Prince                      282.0
# Superman Returns                                              0.0
#
#                                           actor_3_facebook_likes  \
# movie_title
# Avatar                                                     855.0
# Pirates of the Caribbean: At World's End                  1000.0
# Spider-Man 3                                              4000.0
# Harry Potter and the Half-Blood Prince                   10000.0
# Superman Returns                                           903.0
#
#                                               actor_2_name  \
# movie_title
# Avatar                                    Joel David Moore
# Pirates of the Caribbean: At World's End     Orlando Bloom
# Spider-Man 3                                  James Franco
# Harry Potter and the Half-Blood Prince    Daniel Radcliffe
# Superman Returns                             Marlon Brando
#
#                                           actor_1_facebook_likes        gross  \
# movie_title
# Avatar                                                    1000.0  760505847.0
# Pirates of the Caribbean: At World's End                 40000.0  309404152.0
# Spider-Man 3                                             24000.0  336530303.0
# Harry Potter and the Half-Blood Prince                   25000.0  301956980.0
# Superman Returns                                         18000.0  200069408.0
#
#                                                                     genres  \
# movie_title
# Avatar                                     Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End          Action|Adventure|Fantasy
# Spider-Man 3                                      Action|Adventure|Romance
# Harry Potter and the Half-Blood Prince    Adventure|Family|Fantasy|Mystery
# Superman Returns                                   Action|Adventure|Sci-Fi
#
#                                           ... num_user_for_reviews  language  \
# movie_title                               ...
# Avatar                                    ...               3054.0   English
# Pirates of the Caribbean: At World's End  ...               1238.0   English
# Spider-Man 3                              ...               1902.0   English
# Harry Potter and the Half-Blood Prince    ...                973.0   English
# Superman Returns                          ...               2367.0   English
#
#                                           country content_rating       budget  \
# movie_title
# Avatar                                        USA          PG-13  237000000.0
# Pirates of the Caribbean: At World's End      USA          PG-13  300000000.0
# Spider-Man 3                                  USA          PG-13  258000000.0
# Harry Potter and the Half-Blood Prince         UK             PG  250000000.0
# Superman Returns                              USA          PG-13  209000000.0
#
#                                          title_year actor_2_facebook_likes  \
# movie_title
# Avatar                                       2009.0                  936.0
# Pirates of the Caribbean: At World's End     2007.0                 5000.0
# Spider-Man 3                                 2007.0                11000.0
# Harry Potter and the Half-Blood Prince       2009.0                11000.0
# Superman Returns                             2006.0                10000.0
#
#                                           imdb_score aspect_ratio  \
# movie_title
# Avatar                                           7.9         1.78
# Pirates of the Caribbean: At World's End         7.1         2.35
# Spider-Man 3                                     6.2         2.35
# Harry Potter and the Half-Blood Prince           7.5         2.35
# Superman Returns                                 6.1         2.35
#
#                                          movie_facebook_likes
# movie_title
# Avatar                                                33000.0
# Pirates of the Caribbean: At World's End                  0.0
# Spider-Man 3                                              0.0
# Harry Potter and the Half-Blood Prince                10000.0
# Superman Returns                                          0.0
#
# [5 rows x 27 columns]

# %%
# movie_maskと同じ条件でdfを作成
movie_boolean = movie[movie['title_year'] < 2010]
movie_boolean.head()
# Out:
#                                           color   director_name  \
# movie_title
# Avatar                                    Color   James Cameron
# Pirates of the Caribbean: At World's End  Color  Gore Verbinski
# Spider-Man 3                              Color       Sam Raimi
# Harry Potter and the Half-Blood Prince    Color     David Yates
# Superman Returns                          Color    Bryan Singer
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                     723.0     178.0
# Pirates of the Caribbean: At World's End                   302.0     169.0
# Spider-Man 3                                               392.0     156.0
# Harry Potter and the Half-Blood Prince                     375.0     153.0
# Superman Returns                                           434.0     169.0
#
#                                           director_facebook_likes  \
# movie_title
# Avatar                                                        0.0
# Pirates of the Caribbean: At World's End                    563.0
# Spider-Man 3                                                  0.0
# Harry Potter and the Half-Blood Prince                      282.0
# Superman Returns                                              0.0
#
#                                           actor_3_facebook_likes  \
# movie_title
# Avatar                                                     855.0
# Pirates of the Caribbean: At World's End                  1000.0
# Spider-Man 3                                              4000.0
# Harry Potter and the Half-Blood Prince                   10000.0
# Superman Returns                                           903.0
#
#                                               actor_2_name  \
# movie_title
# Avatar                                    Joel David Moore
# Pirates of the Caribbean: At World's End     Orlando Bloom
# Spider-Man 3                                  James Franco
# Harry Potter and the Half-Blood Prince    Daniel Radcliffe
# Superman Returns                             Marlon Brando
#
#                                           actor_1_facebook_likes        gross  \
# movie_title
# Avatar                                                    1000.0  760505847.0
# Pirates of the Caribbean: At World's End                 40000.0  309404152.0
# Spider-Man 3                                             24000.0  336530303.0
# Harry Potter and the Half-Blood Prince                   25000.0  301956980.0
# Superman Returns                                         18000.0  200069408.0
#
#                                                                     genres  \
# movie_title
# Avatar                                     Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End          Action|Adventure|Fantasy
# Spider-Man 3                                      Action|Adventure|Romance
# Harry Potter and the Half-Blood Prince    Adventure|Family|Fantasy|Mystery
# Superman Returns                                   Action|Adventure|Sci-Fi
#
#                                           ... num_user_for_reviews  language  \
# movie_title                               ...
# Avatar                                    ...               3054.0   English
# Pirates of the Caribbean: At World's End  ...               1238.0   English
# Spider-Man 3                              ...               1902.0   English
# Harry Potter and the Half-Blood Prince    ...                973.0   English
# Superman Returns                          ...               2367.0   English
#
#                                           country content_rating       budget  \
# movie_title
# Avatar                                        USA          PG-13  237000000.0
# Pirates of the Caribbean: At World's End      USA          PG-13  300000000.0
# Spider-Man 3                                  USA          PG-13  258000000.0
# Harry Potter and the Half-Blood Prince         UK             PG  250000000.0
# Superman Returns                              USA          PG-13  209000000.0
#
#                                          title_year actor_2_facebook_likes  \
# movie_title
# Avatar                                       2009.0                  936.0
# Pirates of the Caribbean: At World's End     2007.0                 5000.0
# Spider-Man 3                                 2007.0                11000.0
# Harry Potter and the Half-Blood Prince       2009.0                11000.0
# Superman Returns                             2006.0                10000.0
#
#                                           imdb_score aspect_ratio  \
# movie_title
# Avatar                                           7.9         1.78
# Pirates of the Caribbean: At World's End         7.1         2.35
# Spider-Man 3                                     6.2         2.35
# Harry Potter and the Half-Blood Prince           7.5         2.35
# Superman Returns                                 6.1         2.35
#
#                                          movie_facebook_likes
# movie_title
# Avatar                                                  33000
# Pirates of the Caribbean: At World's End                    0
# Spider-Man 3                                                0
# Harry Potter and the Half-Blood Prince                  10000
# Superman Returns                                            0
#
# [5 rows x 27 columns]

# %%
# 同じ条件で作成したdfが等しいか確認
# equalsメソッドはカラムの形が同じでもデータ型が異なるとFalseを返すことに注意
movie_mask.equals(movie_boolean)
# Out:
# False

# %%
# サイズが等しいかを確認
movie_mask.shape == movie_boolean.shape
# Out:
# True

# %%
# データタイプが同じか確認
movie_mask.dtypes == movie_boolean.dtypes
# Out:
# color                         True
# director_name                 True
# num_critic_for_reviews        True
# duration                      True
# director_facebook_likes       True
# actor_3_facebook_likes        True
# actor_2_name                  True
# actor_1_facebook_likes        True
# gross                         True
# genres                        True
# actor_1_name                  True
# num_voted_users              False
# cast_total_facebook_likes    False
# actor_3_name                  True
# facenumber_in_poster          True
# plot_keywords                 True
# movie_imdb_link               True
# num_user_for_reviews          True
# language                      True
# country                       True
# content_rating                True
# budget                        True
# title_year                    True
# actor_2_facebook_likes        True
# imdb_score                    True
# aspect_ratio                  True
# movie_facebook_likes         False
# dtype: bool

# %%
# assert_frame_equal : SeriesとDataFrameの等価性をデータ型の等価性は無視してチェックする
from pandas.testing import assert_frame_equal
assert_frame_equal(movie_boolean, movie_mask, check_dtype=False)

# %%
# マスキングの速度
# %timeit movie.mask(criteria).dropna(how='all')
# Out:
# 7.95 ms ± 99.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Booleanインデックス法の速度
# %timeit movie[movie['title_year'] < 2000]
# Out:
# 579 µs ± 7.89 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# # 44. Boolean, 整数位置, ラベルによる選択

# %%
movie = pd.read_csv('Pandas-Cookbook-master/data/movie.csv', index_col='movie_title')
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
#
#                                                   gross  \
# movie_title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres  \
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
#                                             ... num_user_for_reviews  \
# movie_title                                 ...
# Avatar                                      ...               3054.0
# Pirates of the Caribbean: At World's End    ...               1238.0
# Spectre                                     ...                994.0
# The Dark Knight Rises                       ...               2701.0
# Star Wars: Episode VII - The Force Awakens  ...                  NaN
#
#                                             language  country content_rating  \
# movie_title
# Avatar                                       English      USA          PG-13
# Pirates of the Caribbean: At World's End     English      USA          PG-13
# Spectre                                      English       UK          PG-13
# The Dark Knight Rises                        English      USA          PG-13
# Star Wars: Episode VII - The Force Awakens       NaN      NaN            NaN
#
#                                                  budget title_year  \
# movie_title
# Avatar                                      237000000.0     2009.0
# Pirates of the Caribbean: At World's End    300000000.0     2007.0
# Spectre                                     245000000.0     2015.0
# The Dark Knight Rises                       250000000.0     2012.0
# Star Wars: Episode VII - The Force Awakens          NaN        NaN
#
#                                            actor_2_facebook_likes  imdb_score  \
# movie_title
# Avatar                                                      936.0         7.9
# Pirates of the Caribbean: At World's End                   5000.0         7.1
# Spectre                                                     393.0         6.8
# The Dark Knight Rises                                     23000.0         8.5
# Star Wars: Episode VII - The Force Awakens                   12.0         7.1
#
#                                            aspect_ratio movie_facebook_likes
# movie_title
# Avatar                                             1.78                33000
# Pirates of the Caribbean: At World's End           2.35                    0
# Spectre                                            2.35                85000
# The Dark Knight Rises                              2.35               164000
# Star Wars: Episode VII - The Force Awakens          NaN                    0
#
# [5 rows x 27 columns]

# %%
c1 = movie['content_rating'] == 'G'
c2 = movie['imdb_score'] < 4
criteria = c1 | c2
criteria
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                         False
# Star Wars: Episode VII - The Force Awakens    False
#                                               ...
# Signed Sealed Delivered                       False
# The Following                                 False
# A Plague So Pleasant                          False
# Shanghai Calling                              False
# My Date with Drew                             False
# Length: 4916, dtype: bool

# %%
movie_loc = movie.loc[criteria]
movie_loc.head()
# Out:
#                      color    director_name  num_critic_for_reviews  duration  \
# movie_title
# Monsters University  Color      Dan Scanlon                   376.0     104.0
# Cars 2               Color    John Lasseter                   304.0     106.0
# Toy Story 3          Color      Lee Unkrich                   453.0     103.0
# WALL·E               Color   Andrew Stanton                   421.0      98.0
# The Polar Express    Color  Robert Zemeckis                   188.0     100.0
#
#                      director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Monsters University                     37.0                   760.0
# Cars 2                                 487.0                   776.0
# Toy Story 3                            125.0                   721.0
# WALL·E                                 475.0                   522.0
# The Polar Express                        0.0                   267.0
#
#                            actor_2_name  actor_1_facebook_likes        gross  \
# movie_title
# Monsters University        Tyler Labine                 12000.0  268488329.0
# Cars 2               Thomas Kretschmann                  1000.0  191450875.0
# Toy Story 3           John Ratzenberger                 15000.0  414984497.0
# WALL·E                     Fred Willard                  1000.0  223806889.0
# The Polar Express          Eddie Deezen                 15000.0     665426.0
#
#                                                         genres  ...  \
# movie_title                                                     ...
# Monsters University  Adventure|Animation|Comedy|Family|Fantasy  ...
# Cars 2                 Adventure|Animation|Comedy|Family|Sport  ...
# Toy Story 3          Adventure|Animation|Comedy|Family|Fantasy  ...
# WALL·E                       Adventure|Animation|Family|Sci-Fi  ...
# The Polar Express           Adventure|Animation|Family|Fantasy  ...
#
#                     num_user_for_reviews  language  country content_rating  \
# movie_title
# Monsters University                265.0   English      USA              G
# Cars 2                             283.0   English      USA              G
# Toy Story 3                        733.0   English      USA              G
# WALL·E                            1043.0   English      USA              G
# The Polar Express                  444.0   English      USA              G
#
#                           budget title_year actor_2_facebook_likes  \
# movie_title
# Monsters University  200000000.0     2013.0                  779.0
# Cars 2               200000000.0     2011.0                  919.0
# Toy Story 3          200000000.0     2010.0                 1000.0
# WALL·E               180000000.0     2008.0                  729.0
# The Polar Express    165000000.0     2004.0                  726.0
#
#                      imdb_score aspect_ratio movie_facebook_likes
# movie_title
# Monsters University         7.3         1.85                44000
# Cars 2                      6.3         2.35                10000
# Toy Story 3                 8.3         1.85                30000
# WALL·E                      8.4         2.35                16000
# The Polar Express           6.6         2.35                10000
#
# [5 rows x 27 columns]

# %%
movie_loc.equals(movie[criteria])
# Out:
# True

# %%
# インデックスとしてはndarrayを使わないといけない（Seriesはダメ！）
# criteria.valueでndarrayにする
movie_iloc = movie.iloc[criteria.values]
movie_iloc.equals(movie_loc)
# Out:
# True

# %%
criteria_col = movie.dtypes == np.int64
criteria_col.head()
# Out:
# color                      False
# director_name              False
# num_critic_for_reviews     False
# duration                   False
# director_facebook_likes    False
# dtype: bool

# %%
movie.iloc[:, criteria_col.values].head()
# Out:
#                                             num_voted_users  \
# movie_title
# Avatar                                               886204
# Pirates of the Caribbean: At World's End             471220
# Spectre                                              275868
# The Dark Knight Rises                               1144337
# Star Wars: Episode VII - The Force Awakens                8
#
#                                             cast_total_facebook_likes  \
# movie_title
# Avatar                                                           4834
# Pirates of the Caribbean: At World's End                        48350
# Spectre                                                         11700
# The Dark Knight Rises                                          106759
# Star Wars: Episode VII - The Force Awakens                        143
#
#                                             movie_facebook_likes
# movie_title
# Avatar                                                     33000
# Pirates of the Caribbean: At World's End                       0
# Spectre                                                    85000
# The Dark Knight Rises                                     164000
# Star Wars: Episode VII - The Force Awakens                     0
